# %%
import os, sys

PROJECT_ROOT = os.path.dirname(os.path.dirname(os.path.abspath("..")))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

from src.embeddings.clip_encoder import ClipEncoder
from src.embeddings.vector_store import VectorStore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       4 if PROJECT_ROOT not in sys.path:
#       5     sys.path.append(PROJECT_ROOT)
# ----> 7 from src.embeddings.clip_encoder import ClipEncoder
#       8 from src.embeddings.vector_store import VectorStore
#
# ModuleNotFoundError: No module named 'src.embeddings.clip_encoder'

# %%
encoder = ClipEncoder()
store = VectorStore(dimension=512)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 encoder = ClipEncoder()
#       2 store = VectorStore(dimension=512)
#
# NameError: name 'ClipEncoder' is not defined
